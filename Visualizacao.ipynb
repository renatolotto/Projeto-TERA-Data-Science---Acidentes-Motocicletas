# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('df_acidentes_sp_moto.csv', dtype={'Turno':'category', 'Dia da Semana':'category', 'Condições Climáticas':'category', 'Iluminação':'category', 'Mão de direção':'category', 'Obras na pista':'category', 'Relevo':'category', 'Superfície da via':'category', 'Tipo de pavimento':'category', 'Tipo de pista':'category','Traçado':'category'})

# %%
pd.set_option("display.max_columns", 81)

# %% [markdown]
# olhando os dados

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64621 entries, 0 to 64620
# Data columns (total 79 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   ID                                           64621 non-null  int64
#  1   Data do Acidente                             64621 non-null  object
#  2   Dia do Acidente                              64621 non-null  object
#  3   Mês do Acidente                              64621 non-null  object
#  4   Ano do Acidente                              64621 non-null  object
#  5   Ano/Mês do Acidente                          64621 non-null  float64
#  6   Dia da Semana                                64621 non-null  category
#  7   Hora do Acidente                             64364 non-null  object
#  8   Turno                                        64364 non-null  category
# ...

# %% [markdown]
# vendo os resultados mais frequentes no dataset

# %%
dataset.describe(include=np.object)
# Out:
#        Data do Acidente Dia do Acidente Mês do Acidente Ano do Acidente  \
# count             64621           64621           64621           64621
# unique             2027              31              12              12
# top          2019-11-01      1900-01-12           MARÇO      2019-01-01
# freq                133            2254            6789           29031
#
#        Hora do Acidente  Município       Região Administrativa Logradouro  \
# count             64364      64621                       64621      63777
# unique             2553         39                           1      12794
# top               18:30  SAO PAULO  Metropolitana de São Paulo     SP 015
# freq                147      39220                       64621       1610
#
#        Numero/KM Jurisdição Administração Conservação       Latitude  \
# count      59759      63680         63146       63145          60791
# unique      8438          3             4          15          48770
# ...

# %%
dataset = dataset.replace('NAO DISPONIVEL', np.nan)

# %%
#trocar os nao e sim por binarios
